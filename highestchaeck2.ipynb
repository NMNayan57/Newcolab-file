# %% [markdown]
# <a href="https://colab.research.google.com/github/noyon57/Newcolab-file/blob/main/highestchaeck2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split as split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
data=pd.read_csv('/content/Maternal Health Risk Data Set.csv')

# %%
data.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1014 entries, 0 to 1013
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          1014 non-null   int64
#  1   SystolicBP   1014 non-null   int64
#  2   DiastolicBP  1014 non-null   int64
#  3   BS           1014 non-null   float64
#  4   BodyTemp     1014 non-null   float64
#  5   HeartRate    1014 non-null   int64
#  6   RiskLevel    1014 non-null   object
# dtypes: float64(2), int64(4), object(1)
# memory usage: 55.6+ KB

# %%
data.isnull().sum()
# Out:
# Age            0
# SystolicBP     0
# DiastolicBP    0
# BS             0
# BodyTemp       0
# HeartRate      0
# RiskLevel      0
# dtype: int64

# %%
print(f"There are {data.duplicated().sum()} duplicates data")
data.loc[data.duplicated(keep=False)].sort_values(by=data.columns.to_list())
# Out:
# There are 562 duplicates data
#      Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 670   10         100           50   6.0      99.0         70   mid risk
# 849   10         100           50   6.0      99.0         70   mid risk
# 552   12          90           60   7.5     102.0         60   low risk
# 940   12          90           60   7.5     102.0         60   low risk
# 543   12          90           60   7.5     102.0         66   low risk
# ..   ...         ...          ...   ...       ...        ...        ...
# 553   60         120           85  15.0      98.0         60   mid risk
# 772   60         120           85  15.0      98.0         60   mid risk
# 818   60         120           85  15.0      98.0         60   mid risk
# 114   63         140           90  15.0      98.0         90  high risk
# 502   63         140           90  15.0      98.0         90  high risk
#
# [866 rows x 7 columns]

# %%
p_colors = ['green', 'orange', 'red']
risk_order = ["low risk", "mid risk", "high risk"]
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

data["RiskLevel"].value_counts().plot(kind="pie", labels=risk_order, colors=p_colors, explode=[0.05, 0.05,  0.05], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title("Risk Level Pie Chart")
ax[0].set_ylabel('')

count = sns.countplot(x="RiskLevel", data=data, ax=ax[1], order=risk_order, palette=p_colors)
for bar in count.patches:
    count.annotate(format(bar.get_height()),
        (bar.get_x() + bar.get_width() / 2,
        bar.get_height()), ha='center', va='center',
        size=11, xytext=(0, 8),
        textcoords='offset points')
ax[1].set_title("Risk Level Bar Chart")
plt.show()

# %%
data.describe().T
# Out:
#               count        mean        std   min    25%    50%    75%    max
# Age          1014.0   29.871795  13.474386  10.0   19.0   26.0   39.0   70.0
# SystolicBP   1014.0  113.198225  18.403913  70.0  100.0  120.0  120.0  160.0
# DiastolicBP  1014.0   76.460552  13.885796  49.0   65.0   80.0   90.0  100.0
# BS           1014.0    8.725986   3.293532   6.0    6.9    7.5    8.0   19.0
# BodyTemp     1014.0   98.665089   1.371384  98.0   98.0   98.0   98.0  103.0
# HeartRate    1014.0   74.301775   8.088702   7.0   70.0   76.0   80.0   90.0

# %%
def num_plot(data, col):
    fig, ax = plt.subplots(1, 2, figsize=(12, 4))

    sns.histplot(data=data, x=col, kde=True, ax=ax[0])
    sns.boxplot(data=data, x=col, ax=ax[1])
    ax[0].set_title(f"{col} Distribution Histogram")
    ax[1].set_title(f"{col} Distribution Boxplot")

    plt.show()

# %%
num_plot(data, "Age")

# %%
num_plot(data, "SystolicBP")

# %%
num_plot(data, "DiastolicBP")

# %%
sns.heatmap(data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %% [markdown]
# Observation: SystolicBP and DiastolicBP are highly correlated. As we can see from the graph, they have positive correlation with correlation coefficient value = 0.79. This means that SystolicBP and DiastolicBP variable contains highly similar information and there is very little or no variance in information. This is known as a problem called MultiColinearity, which undermines the statistical significance of an independent variable. We can remove one of them because we don't want a redundant variable while making or training our model. But we will try to dig deeper to decide whether we need to remove these variable, and which variable we should remove

# %%
sns.histplot(data=data, x="Age", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.Age).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_1f7de_row0_col0, #T_1f7de_row0_col1, #T_1f7de_row0_col4, #T_1f7de_row0_col5, #T_1f7de_row0_col7, #T_1f7de_row0_col8, #T_1f7de_row0_col9, #T_1f7de_row0_col10, #T_1f7de_row0_col11, #T_1f7de_row0_col12, #T_1f7de_row0_col13, #T_1f7de_row0_col15, #T_1f7de_row0_col16, #T_1f7de_row0_col17, #T_1f7de_row0_col20, #T_1f7de_row0_col30, #T_1f7de_row0_col31, #T_1f7de_row0_col33, #T_1f7de_row0_col37, #T_1f7de_row0_col39, #T_1f7de_row0_col43, #T_1f7de_row0_col44, #T_1f7de_row0_col45, #T_1f7de_row0_col48, #T_1f7de_row0_col49, #T_1f7de_row1_col2, #T_1f7de_row1_col3, #T_1f7de_row1_col6, #T_1f7de_row1_col15, #T_1f7de_row1_col18, #T_1f7de_row1_col19, #T_1f7de_row1_col22, #T_1f7de_row1_col25, #T_1f7de_row1_col26, #T_1f7de_row1_col27, #T_1f7de_row1_col28, #T_1f7de_row1_col29, #T_1f7de_row1_col32, #T_1f7de_row1_col33, #T_1f7de_row1_col35, #T_1f7de_row1_col36, #T_1f7de_row1_col38, #T_1f7de_row1_col40, #T_1f7de_row1_col42, #T_1f7de_row1_col46, #T_1f7de_row2_col3, #T_1f7de_row2_col13, #T_1f7de_row2_col14, #T_1f7de_row2_col16, #T_1f7de_row2_col21, #T_1f7de_row2_col23, #T_1f7de_row2_col24, #T_1f7de_row2_col26, #T_1f7de_row2_col27, #T_1f7de_row2_col30, #T_1f7de_row2_col31, #T_1f7de_row2_col34, #T_1f7de_row2_col35, #T_1f7de_row2_col37, #T_1f7de_row2_col39, #T_1f7de_row2_col41, #T_1f7de_row2_col42, #T_1f7de_row2_col43, #T_1f7de_row2_col45, #T_1f7de_row2_col46, #T_1f7de_row2_col47, #T_1f7de_row2_col48, #T_1f7de_row2_col49 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_1f7de_row0_col2 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_1f7de_row0_col3, #T_1f7de_row0_col6, #T_1f7de_row0_col14, #T_1f7de_row0_col21, #T_1f7de_row0_col23, #T_1f7de_row0_col24, #T_1f7de_row0_col25, #T_1f7de_row0_col26, #T_1f7de_row0_col27, #T_1f7de_row0_col28, #T_1f7de_row0_col29, #T_1f7de_row0_col32, #T_1f7de_row0_col35, #T_1f7de_row0_col36, #T_1f7de_row0_col38, #T_1f7de_row0_col40, #T_1f7de_row0_col41, #T_1f7de_row0_col42, #T_1f7de_row0_col46, #T_1f7de_row1_col0, #T_1f7de_row1_col1, #T_1f7de_row1_col4, #T_1f7de_row1_col5, #T_1f7de_row1_col9, #T_1f7de_row1_col10, #T_1f7de_row1_col11, #T_1f7de_row1_col12, #T_1f7de_row1_col13, #T_1f7de_row1_col16, #T_1f7de_row1_col21, #T_1f7de_row1_col30, #T_1f7de_row1_col31, #T_1f7de_row1_col34, #T_1f7de_row1_col37, #T_1f7de_row1_col39, #T_1f7de_row1_col43, #T_1f7de_row1_col45, #T_1f7de_row1_col47, #T_1f7de_row1_col48, #T_1f7de_row1_col49, #T_1f7de_row2_col0, #T_1f7de_row2_col2, #T_1f7de_row2_col7, #T_1f7de_row2_col8, #T_1f7de_row2_col9, #T_1f7de_row2_col15, #T_1f7de_row2_col17, #T_1f7de_row2_col18, #T_1f7de_row2_col19, #T_1f7de_row2_col20, #T_1f7de_row2_col22, #T_1f7de_row2_col25, #T_1f7de_row2_col28, #T_1f7de_row2_col33, #T_1f7de_row2_col44 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_1f7de_row0_col18 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_1f7de_row0_col19, #T_1f7de_row0_col47, #T_1f7de_row1_col14, #T_1f7de_row2_col6 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_1f7de_row0_col22, #T_1f7de_row1_col23, #T_1f7de_row2_col32 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_1f7de_row0_col34 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_1f7de_row1_col7 {
#   background-color: #45a266;
#   color: #f1f1f1;
# }
# #T_1f7de_row1_col8 {
#   background-color: #41a066;
#   color: #f1f1f1;
# }
# #T_1f7de_row1_col17 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_1f7de_row1_col20 {
#   background-color: #88c366;
#   color: #000000;
# }
# #T_1f7de_row1_col24 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_1f7de_row1_col41 {
#   background-color: #8ec666;
#   color: #000000;
# }
# #T_1f7de_row1_col44 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_1f7de_row2_col1 {
#   background-color: #3f9f66;
#   color: #f1f1f1;
# }
# #T_1f7de_row2_col4 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_1f7de_row2_col5 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_1f7de_row2_col10 {
#   background-color: #97cb66;
#   color: #000000;
# }
# #T_1f7de_row2_col11 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_1f7de_row2_col12 {
#   background-color: #7cbe66;
#   color: #000000;
# }
# #T_1f7de_row2_col29 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_1f7de_row2_col36 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_1f7de_row2_col38 {
#   background-color: #5aac66;
#   color: #f1f1f1;
# }
# #T_1f7de_row2_col40 {
#   background-color: #aad466;
#   color: #000000;
# }
# </style>
# <table id="T_1f7de_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Age</th>
#       <th class="col_heading level0 col0" >10</th>
#       <th class="col_heading level0 col1" >12</th>
#       <th class="col_heading level0 col2" >13</th>
#       <th class="col_heading level0 col3" >14</th>
#       <th class="col_heading level0 col4" >15</th>
#       <th class="col_heading level0 col5" >16</th>
#       <th class="col_heading level0 col6" >17</th>
#       <th class="col_heading level0 col7" >18</th>
#       <th class="col_heading level0 col8" >19</th>
#       <th class="col_heading level0 col9" >20</th>
#       <th class="col_heading level0 col10" >21</th>
#       <th class="col_heading level0 col11" >22</th>
#       <th class="col_heading level0 col12" >23</th>
#       <th class="col_heading level0 col13" >24</th>
#       <th class="col_heading level0 col14" >25</th>
#       <th class="col_heading level0 col15" >26</th>
#       <th class="col_heading level0 col16" >27</th>
#       <th class="col_heading level0 col17" >28</th>
#       <th class="col_heading level0 col18" >29</th>
#       <th class="col_heading level0 col19" >30</th>
#       <th class="col_heading level0 col20" >31</th>
#       <th class="col_heading level0 col21" >32</th>
#       <th class="col_heading level0 col22" >33</th>
#       <th class="col_heading level0 col23" >34</th>
#       <th class="col_heading level0 col24" >35</th>
#       <th class="col_heading level0 col25" >36</th>
#       <th class="col_heading level0 col26" >37</th>
#       <th class="col_heading level0 col27" >38</th>
#       <th class="col_heading level0 col28" >39</th>
#       <th class="col_heading level0 col29" >40</th>
#       <th class="col_heading level0 col30" >41</th>
#       <th class="col_heading level0 col31" >42</th>
#       <th class="col_heading level0 col32" >43</th>
#       <th class="col_heading level0 col33" >44</th>
#       <th class="col_heading level0 col34" >45</th>
#       <th class="col_heading level0 col35" >46</th>
#       <th class="col_heading level0 col36" >48</th>
#       <th class="col_heading level0 col37" >49</th>
#       <th class="col_heading level0 col38" >50</th>
#       <th class="col_heading level0 col39" >51</th>
#       <th class="col_heading level0 col40" >54</th>
#       <th class="col_heading level0 col41" >55</th>
#       <th class="col_heading level0 col42" >56</th>
#       <th class="col_heading level0 col43" >59</th>
#       <th class="col_heading level0 col44" >60</th>
#       <th class="col_heading level0 col45" >62</th>
#       <th class="col_heading level0 col46" >63</th>
#       <th class="col_heading level0 col47" >65</th>
#       <th class="col_heading level0 col48" >66</th>
#       <th class="col_heading level0 col49" >70</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >

# %% [markdown]
# Observation:
#
# Pregnant women aged below 24 years mostly has low health risk.
# Health risks will start to increase after that age (starting from the age of 25 years).
# Surprisingly, the health risk of pregnant women over 59 years old is decreased

# %%
sns.histplot(data=data, x="SystolicBP", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.SystolicBP).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_55fe1_row0_col0, #T_55fe1_row0_col1, #T_55fe1_row0_col2, #T_55fe1_row0_col3, #T_55fe1_row0_col4, #T_55fe1_row0_col7, #T_55fe1_row0_col8, #T_55fe1_row0_col9, #T_55fe1_row0_col10, #T_55fe1_row0_col12, #T_55fe1_row0_col13, #T_55fe1_row0_col14, #T_55fe1_row1_col5, #T_55fe1_row1_col6, #T_55fe1_row1_col11, #T_55fe1_row1_col12, #T_55fe1_row1_col15, #T_55fe1_row1_col16, #T_55fe1_row1_col17, #T_55fe1_row1_col18, #T_55fe1_row2_col1, #T_55fe1_row2_col2, #T_55fe1_row2_col3, #T_55fe1_row2_col4, #T_55fe1_row2_col5, #T_55fe1_row2_col9, #T_55fe1_row2_col14, #T_55fe1_row2_col16, #T_55fe1_row2_col18 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_55fe1_row0_col5, #T_55fe1_row0_col16, #T_55fe1_row0_col17, #T_55fe1_row0_col18, #T_55fe1_row1_col0, #T_55fe1_row1_col1, #T_55fe1_row1_col2, #T_55fe1_row1_col3, #T_55fe1_row1_col4, #T_55fe1_row1_col7, #T_55fe1_row1_col8, #T_55fe1_row1_col9, #T_55fe1_row1_col10, #T_55fe1_row1_col13, #T_55fe1_row1_col14, #T_55fe1_row2_col6, #T_55fe1_row2_col11, #T_55fe1_row2_col12, #T_55fe1_row2_col15 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_55fe1_row0_col6, #T_55fe1_row0_col15 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_55fe1_row0_col11 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_55fe1_row2_col0 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_55fe1_row2_col7 {
#   background-color: #96cb66;
#   color: #000000;
# }
# #T_55fe1_row2_col8 {
#   background-color: #b6db66;
#   color: #000000;
# }
# #T_55fe1_row2_col10 {
#   background-color: #b7db66;
#   color: #000000;
# }
# #T_55fe1_row2_col13 {
#   background-color: #44a266;
#   color: #f1f1f1;
# }
# #T_55fe1_row2_col17 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# </style>
# <table id="T_55fe1_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >SystolicBP</th>
#       <th class="col_heading level0 col0" >70</th>
#       <th class="col_heading level0 col1" >75</th>
#       <th class="col_heading level0 col2" >76</th>
#       <th class="col_heading level0 col3" >78</th>
#       <th class="col_heading level0 col4" >80</th>
#       <th class="col_heading level0 col5" >83</th>
#       <th class="col_heading level0 col6" >85</th>
#       <th class="col_heading level0 col7" >90</th>
#       <th class="col_heading level0 col8" >95</th>
#       <th class="col_heading level0 col9" >99</th>
#       <th class="col_heading level0 col10" >100</th>
#       <th class="col_heading level0 col11" >110</th>
#       <th class="col_heading level0 col12" >115</th>
#       <th class="col_heading level0 col13" >120</th>
#       <th class="col_heading level0 col14" >129</th>
#       <th class="col_heading level0 col15" >130</th>
#       <th class="col_heading level0 col16" >135</th>
#       <th class="col_heading level0 col17" >140</th>
#       <th class="col_heading level0 col18" >160</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55fe1_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_55fe1_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_55fe1_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_55fe1_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_55fe1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_55fe1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_55fe1_row0_col5" class="data row0 col5" >2</td>
#       <td id="T_55fe1_row0_col6" class="data row0 col6" >13</td>
#       <td id="T_55fe1_row0_col7" class="data row0 col7" >33</td>
#       <td id="T_55fe1_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_55fe1_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_55fe1_row0_col10" class="data row0 col10" >5</td>
#       <td id="T_55fe1_row0_col11" class="data row0 col11" >8</td>
#       <td id="T_55fe1_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_55fe1_row0_col13" class="data row0 col13" >70</td>
#       <td id="T_55fe1_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_55fe1_row0_col15" class="data row0 col15" >12</td>
#       <td id="T_55fe1_row0_col16" class="data row0 col16" >3</td>
#       <td id="T_55fe1_row0_col17" class="data row0 col17" >115</td>
#       <td id="T_55fe1_row0_col18" class="data row0 col18" >10</td>
#     </tr>
#     <tr>
#       <th id="T_55fe1_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_55fe1_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_55fe1_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_55fe1_row1_col2" class="data row1 col2" >16</td>
#       <td id="T_55fe1_row1_col3" class="data row1 col3" >3</td>
#       <td id="T_55fe1_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_55fe1_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_55fe1_row1_col6" class="data row1 col6" >11</td>
#       <td id="T_55fe1_row1_col7" class="data row1 col7" >72</td>
#       <td id="T_55fe1_row1_col8" class="data row1 col8" >8</td>
#       <td id="T_55fe1_row1_col9" class="data row1 col9" >2</td>
#       <td id="T_55fe1_row1_col10" class="data row1 col10" >65</td>
#       <td id="T_55fe1_row1_col11" class="data row1 col11" >2</td>
#       <td id="T_55fe1_row1_col12" class="data row1 col12" >0</td>
#       <td id="T_55fe1_row1_col13" class="data row1 col13" >208</td>
#       <td id="T_55fe1_row1_col14" class="data row1 col14" >1</td>
#       <td id="T_55fe1_row1_col15" class="data row1 col15" >0</td>
#       <td id="T_55fe1_row1_col16" class="data row1 col16" >0</td>
#       <td id="T_55fe1_row1_col17" class="data row1 col17" >0</td>
#       <td id="T_55fe1_row1_col18" class="data row1 col18" >0</td>
#     </tr>
#     <tr>
#       <th id="T_55fe1_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_55fe1_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_55fe1_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_55fe1_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_55fe1_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_55fe1_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_55fe1_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_55fe1_row2_col6" class="data row2 col6" >19</td>
#       <td id="T_55fe1_row2_col7" class="data row2 col7" >49</td>
#       <td id="T_55fe1_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_55fe1_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_55fe1_row2_col10" class="data row2 col10" >22</td>
#       <td id="T_55fe1_row2_col11" class="data row2 col11" >9</td>
#       <td id="T_55fe1_row2_col12" class="data row2 col12" >8</td>
#       <td id="T_55fe1_row2_col13" class="data row2 col13" >171</td>
#       <td id="T_55fe1_row2_col14" class="data row2 col14" >0</td>
#       <td id="T_55fe1_row2_col15" class="data row2 col15" >48</td>
#       <td id="T_55fe1_row2_col16" class="data row2 col16" >0</td>
#       <td id="T_55fe1_row2_col17" class="data row2 col17" >5</td>
#       <td id="T_55fe1_row2_col18" class="data row2 col18" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=data, x="DiastolicBP", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.DiastolicBP).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_33ffd_row0_col0, #T_33ffd_row0_col1, #T_33ffd_row0_col2, #T_33ffd_row0_col3, #T_33ffd_row0_col4, #T_33ffd_row0_col5, #T_33ffd_row0_col7, #T_33ffd_row0_col9, #T_33ffd_row0_col10, #T_33ffd_row0_col11, #T_33ffd_row0_col12, #T_33ffd_row1_col3, #T_33ffd_row1_col6, #T_33ffd_row1_col15, #T_33ffd_row2_col0, #T_33ffd_row2_col5, #T_33ffd_row2_col6, #T_33ffd_row2_col8, #T_33ffd_row2_col9, #T_33ffd_row2_col12, #T_33ffd_row2_col13, #T_33ffd_row2_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_33ffd_row0_col6, #T_33ffd_row0_col14, #T_33ffd_row0_col15, #T_33ffd_row1_col0, #T_33ffd_row1_col1, #T_33ffd_row1_col2, #T_33ffd_row1_col4, #T_33ffd_row1_col5, #T_33ffd_row1_col8, #T_33ffd_row1_col9, #T_33ffd_row1_col10, #T_33ffd_row1_col11, #T_33ffd_row1_col12, #T_33ffd_row1_col13, #T_33ffd_row2_col3, #T_33ffd_row2_col7 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_33ffd_row0_col8 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_33ffd_row0_col13 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_33ffd_row1_col7, #T_33ffd_row2_col4 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_33ffd_row1_col14 {
#   background-color: #bcde66;
#   color: #000000;
# }
# #T_33ffd_row2_col1 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_33ffd_row2_col2 {
#   background-color: #3e9e66;
#   color: #f1f1f1;
# }
# #T_33ffd_row2_col10 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_33ffd_row2_col11 {
#   background-color: #a4d266;
#   color: #000000;
# }
# #T_33ffd_row2_col15 {
#   background-color: #eff766;
#   color: #000000;
# }
# </style>
# <table id="T_33ffd_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >DiastolicBP</th>
#       <th class="col_heading level0 col0" >49</th>
#       <th class="col_heading level0 col1" >50</th>
#       <th class="col_heading level0 col2" >60</th>
#       <th class="col_heading level0 col3" >63</th>
#       <th class="col_heading level0 col4" >65</th>
#       <th class="col_heading level0 col5" >68</th>
#       <th class="col_heading level0 col6" >69</th>
#       <th class="col_heading level0 col7" >70</th>
#       <th class="col_heading level0 col8" >75</th>
#       <th class="col_heading level0 col9" >76</th>
#       <th class="col_heading level0 col10" >80</th>
#       <th class="col_heading level0 col11" >85</th>
#       <th class="col_heading level0 col12" >89</th>
#       <th class="col_heading level0 col13" >90</th>
#       <th class="col_heading level0 col14" >95</th>
#       <th class="col_heading level0 col15" >100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33ffd_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_33ffd_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_33ffd_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_33ffd_row0_col2" class="data row0 col2" >34</td>
#       <td id="T_33ffd_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_33ffd_row0_col4" class="data row0 col4" >14</td>
#       <td id="T_33ffd_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_33ffd_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_33ffd_row0_col7" class="data row0 col7" >10</td>
#       <td id="T_33ffd_row0_col8" class="data row0 col8" >12</td>
#       <td id="T_33ffd_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_33ffd_row0_col10" class="data row0 col10" >38</td>
#       <td id="T_33ffd_row0_col11" class="data row0 col11" >10</td>
#       <td id="T_33ffd_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_33ffd_row0_col13" class="data row0 col13" >48</td>
#       <td id="T_33ffd_row0_col14" class="data row0 col14" >23</td>
#       <td id="T_33ffd_row0_col15" class="data row0 col15" >80</td>
#     </tr>
#     <tr>
#       <th id="T_33ffd_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_33ffd_row1_col0" class="data row1 col0" >25</td>
#       <td id="T_33ffd_row1_col1" class="data row1 col1" >16</td>
#       <td id="T_33ffd_row1_col2" class="data row1 col2" >75</td>
#       <td id="T_33ffd_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_33ffd_row1_col4" class="data row1 col4" >41</td>
#       <td id="T_33ffd_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_33ffd_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_33ffd_row1_col7" class="data row1 col7" >38</td>
#       <td id="T_33ffd_row1_col8" class="data row1 col8" >15</td>
#       <td id="T_33ffd_row1_col9" class="data row1 col9" >3</td>
#       <td id="T_33ffd_row1_col10" class="data row1 col10" >96</td>
#       <td id="T_33ffd_row1_col11" class="data row1 col11" >24</td>
#       <td id="T_33ffd_row1_col12" class="data row1 col12" >1</td>
#       <td id="T_33ffd_row1_col13" class="data row1 col13" >58</td>
#       <td id="T_33ffd_row1_col14" class="data row1 col14" >9</td>
#       <td id="T_33ffd_row1_col15" class="data row1 col15" >1</td>
#     </tr>
#     <tr>
#       <th id="T_33ffd_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_33ffd_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_33ffd_row2_col1" class="data row2 col1" >8</td>
#       <td id="T_33ffd_row2_col2" class="data row2 col2" >65</td>
#       <td id="T_33ffd_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_33ffd_row2_col4" class="data row2 col4" >32</td>
#       <td id="T_33ffd_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_33ffd_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_33ffd_row2_col7" class="data row2 col7" >52</td>
#       <td id="T_33ffd_row2_col8" class="data row2 col8" >11</td>
#       <td id="T_33ffd_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_33ffd_row2_col10" class="data row2 col10" >92</td>
#       <td id="T_33ffd_row2_col11" class="data row2 col11" >15</td>
#       <td id="T_33ffd_row2_col12" class="data row2 col12" >0</td>
#       <td id="T_33ffd_row2_col13" class="data row2 col13" >47</td>
#       <td id="T_33ffd_row2_col14" class="data row2 col14" >4</td>
#       <td id="T_33ffd_row2_col15" class="data row2 col15" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=data, x="BS", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.BS).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_50c1e_row0_col0, #T_50c1e_row0_col1, #T_50c1e_row0_col3, #T_50c1e_row0_col4, #T_50c1e_row0_col5, #T_50c1e_row0_col6, #T_50c1e_row0_col7, #T_50c1e_row0_col8, #T_50c1e_row0_col9, #T_50c1e_row0_col11, #T_50c1e_row0_col13, #T_50c1e_row0_col14, #T_50c1e_row0_col16, #T_50c1e_row0_col17, #T_50c1e_row1_col2, #T_50c1e_row1_col10, #T_50c1e_row1_col18, #T_50c1e_row1_col19, #T_50c1e_row1_col20, #T_50c1e_row1_col21, #T_50c1e_row1_col22, #T_50c1e_row1_col23, #T_50c1e_row1_col24, #T_50c1e_row1_col25, #T_50c1e_row1_col26, #T_50c1e_row1_col27, #T_50c1e_row1_col28, #T_50c1e_row2_col2, #T_50c1e_row2_col4, #T_50c1e_row2_col5, #T_50c1e_row2_col11, #T_50c1e_row2_col12, #T_50c1e_row2_col14, #T_50c1e_row2_col15, #T_50c1e_row2_col20, #T_50c1e_row2_col23, #T_50c1e_row2_col26, #T_50c1e_row2_col28 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_50c1e_row0_col2, #T_50c1e_row0_col18, #T_50c1e_row0_col20, #T_50c1e_row0_col21, #T_50c1e_row0_col22, #T_50c1e_row0_col23, #T_50c1e_row0_col24, #T_50c1e_row0_col26, #T_50c1e_row0_col27, #T_50c1e_row0_col28, #T_50c1e_row1_col1, #T_50c1e_row1_col3, #T_50c1e_row1_col4, #T_50c1e_row1_col5, #T_50c1e_row1_col11, #T_50c1e_row1_col12, #T_50c1e_row1_col13, #T_50c1e_row1_col14, #T_50c1e_row1_col15, #T_50c1e_row1_col17, #T_50c1e_row2_col0, #T_50c1e_row2_col6, #T_50c1e_row2_col7, #T_50c1e_row2_col8, #T_50c1e_row2_col9, #T_50c1e_row2_col10, #T_50c1e_row2_col16, #T_50c1e_row2_col19, #T_50c1e_row2_col25 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_50c1e_row0_col10, #T_50c1e_row1_col0, #T_50c1e_row2_col22 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_50c1e_row0_col12 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_50c1e_row0_col15 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_50c1e_row0_col19 {
#   background-color: #5eae66;
#   color: #f1f1f1;
# }
# #T_50c1e_row0_col25 {
#   background-color: #1c8e66;
#   color: #f1f1f1;
# }
# #T_50c1e_row1_col6 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_50c1e_row1_col7 {
#   background-color: #219066;
#   color: #f1f1f1;
# }
# #T_50c1e_row1_col8 {
#   background-color: #389c66;
#   color: #f1f1f1;
# }
# #T_50c1e_row1_col9 {
#   background-color: #5faf66;
#   color: #f1f1f1;
# }
# #T_50c1e_row1_col16 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_50c1e_row2_col1 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_50c1e_row2_col3, #T_50c1e_row2_col18 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_50c1e_row2_col13 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_50c1e_row2_col17 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_50c1e_row2_col21 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_50c1e_row2_col24 {
#   background-color: #e5f266;
#   color: #000000;
# }
# #T_50c1e_row2_col27 {
#   background-color: #d7eb66;
#   color: #000000;
# }
# </style>
# <table id="T_50c1e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >BS</th>
#       <th class="col_heading level0 col0" >6.0</th>
#       <th class="col_heading level0 col1" >6.1</th>
#       <th class="col_heading level0 col2" >6.3</th>
#       <th class="col_heading level0 col3" >6.4</th>
#       <th class="col_heading level0 col4" >6.5</th>
#       <th class="col_heading level0 col5" >6.6</th>
#       <th class="col_heading level0 col6" >6.7</th>
#       <th class="col_heading level0 col7" >6.8</th>
#       <th class="col_heading level0 col8" >6.9</th>
#       <th class="col_heading level0 col9" >7.0</th>
#       <th class="col_heading level0 col10" >7.01</th>
#       <th class="col_heading level0 col11" >7.1</th>
#       <th class="col_heading level0 col12" >7.2</th>
#       <th class="col_heading level0 col13" >7.5</th>
#       <th class="col_heading level0 col14" >7.6</th>
#       <th class="col_heading level0 col15" >7.7</th>
#       <th class="col_heading level0 col16" >7.8</th>
#       <th class="col_heading level0 col17" >7.9</th>
#       <th class="col_heading level0 col18" >8.0</th>
#       <th class="col_heading level0 col19" >9.0</th>
#       <th class="col_heading level0 col20" >10.0</th>
#       <th class="col_heading level0 col21" >11.0</th>
#       <th class="col_heading level0 col22" >12.0</th>
#       <th class="col_heading level0 col23" >13.0</th>
#       <th class="col_heading level0 col24" >15.0</th>
#       <th class="col_heading level0 col25" >16.0</th>
#       <th class="col_heading level0 col26" >17.0</th>
#       <th class="col_heading level0 col27" >18.0</th>
#       <th class="col_heading level0 col28" >19.0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50c1e_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_50c1e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_50c1e_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_50c1e_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_50c1e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_50c1e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_50c1e_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_50c1e_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_50c1e_row0_col7" class="data row0 col7" >10</td>
#       <td id="T_50c1e_row0_col8" class="data row0 col8" >8</td>
#       <td id="T_50c1e_row0_col9" class="data row0 col9" >9</td>
#       <td id="T_50c1e_row0_col10" class="data row0 col10" >5</td>
#       <td id="T_50c1e_row0_col11" class="data row0 col11" >0</td>
#       <td id="T_50c1e_row0_col12" class="data row0 col12" >6</td>
#       <td id="T_50c1e_row0_col13" class="data row0 col13" >11</td>
#       <td id="T_50c1e_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_50c1e_row0_col15" class="data row0 col15" >4</td>
#       <td id="T_50c1e_row0_col16" class="data row0 col16" >5</td>
#       <td id="T_50c1e_row0_col17" class="data row0 col17" >12</td>
#       <td id="T_50c1e_row0_col18" class="data row0 col18" >12</td>
#       <td id="T_50c1e_row0_col19" class="data row0 col19" >12</td>
#       <td id="T_50c1e_row0_col20" class="data row0 col20" >4</td>
#       <td id="T_50c1e_row0_col21" class="data row0 col21" >40</td>
#       <td id="T_50c1e_row0_col22" class="data row0 col22" >12</td>
#       <td id="T_50c1e_row0_col23" class="data row0 col23" >9</td>
#       <td id="T_50c1e_row0_col24" class="data row0 col24" >49</td>
#       <td id="T_50c1e_row0_col25" class="data row0 col25" >8</td>
#       <td id="T_50c1e_row0_col26" class="data row0 col26" >5</td>
#       <td id="T_50c1e_row0_col27" class="data row0 col27" >25</td>
#       <td id="T_50c1e_row0_col28" class="data row0 col28" >22</td>
#     </tr>
#     <tr>
#       <th id="T_50c1e_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_50c1e_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_50c1e_row1_col1" class="data row1 col1" >32</td>
#       <td id="

# %%
sns.histplot(data=data, x="BodyTemp", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.BodyTemp).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_6f1c9_row0_col0, #T_6f1c9_row0_col1, #T_6f1c9_row0_col3, #T_6f1c9_row1_col2, #T_6f1c9_row1_col4, #T_6f1c9_row1_col5, #T_6f1c9_row1_col6, #T_6f1c9_row2_col1, #T_6f1c9_row2_col2, #T_6f1c9_row2_col3, #T_6f1c9_row2_col7 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_6f1c9_row0_col2, #T_6f1c9_row0_col6, #T_6f1c9_row0_col7, #T_6f1c9_row1_col0, #T_6f1c9_row1_col1, #T_6f1c9_row1_col3, #T_6f1c9_row2_col4, #T_6f1c9_row2_col5 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_6f1c9_row0_col4 {
#   background-color: #badc66;
#   color: #000000;
# }
# #T_6f1c9_row0_col5 {
#   background-color: #71b866;
#   color: #f1f1f1;
# }
# #T_6f1c9_row1_col7 {
#   background-color: #3f9f66;
#   color: #f1f1f1;
# }
# #T_6f1c9_row2_col0 {
#   background-color: #b4da66;
#   color: #000000;
# }
# #T_6f1c9_row2_col6 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6f1c9_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >BodyTemp</th>
#       <th class="col_heading level0 col0" >98.0</th>
#       <th class="col_heading level0 col1" >98.4</th>
#       <th class="col_heading level0 col2" >98.6</th>
#       <th class="col_heading level0 col3" >99.0</th>
#       <th class="col_heading level0 col4" >100.0</th>
#       <th class="col_heading level0 col5" >101.0</th>
#       <th class="col_heading level0 col6" >102.0</th>
#       <th class="col_heading level0 col7" >103.0</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f1c9_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_6f1c9_row0_col0" class="data row0 col0" >199</td>
#       <td id="T_6f1c9_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_6f1c9_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_6f1c9_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_6f1c9_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_6f1c9_row0_col5" class="data row0 col5" >34</td>
#       <td id="T_6f1c9_row0_col6" class="data row0 col6" >25</td>
#       <td id="T_6f1c9_row0_col7" class="data row0 col7" >6</td>
#     </tr>
#     <tr>
#       <th id="T_6f1c9_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_6f1c9_row1_col0" class="data row1 col0" >359</td>
#       <td id="T_6f1c9_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_6f1c9_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_6f1c9_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_6f1c9_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_6f1c9_row1_col5" class="data row1 col5" >14</td>
#       <td id="T_6f1c9_row1_col6" class="data row1 col6" >18</td>
#       <td id="T_6f1c9_row1_col7" class="data row1 col7" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6f1c9_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_6f1c9_row2_col0" class="data row2 col0" >246</td>
#       <td id="T_6f1c9_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_6f1c9_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_6f1c9_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_6f1c9_row2_col4" class="data row2 col4" >13</td>
#       <td id="T_6f1c9_row2_col5" class="data row2 col5" >50</td>
#       <td id="T_6f1c9_row2_col6" class="data row2 col6" >23</td>
#       <td id="T_6f1c9_row2_col7" class="data row2 col7" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.histplot(data=data, x="HeartRate", hue="RiskLevel", kde=True, hue_order=risk_order, palette=p_colors)
plt.show()

# %%
pd.crosstab(data.RiskLevel, data.HeartRate).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_e5bf1_row0_col0, #T_e5bf1_row0_col1, #T_e5bf1_row0_col2, #T_e5bf1_row0_col5, #T_e5bf1_row0_col6, #T_e5bf1_row0_col7, #T_e5bf1_row0_col8, #T_e5bf1_row0_col12, #T_e5bf1_row1_col4, #T_e5bf1_row1_col5, #T_e5bf1_row1_col10, #T_e5bf1_row1_col13, #T_e5bf1_row1_col15, #T_e5bf1_row2_col0, #T_e5bf1_row2_col3, #T_e5bf1_row2_col7, #T_e5bf1_row2_col9, #T_e5bf1_row2_col11, #T_e5bf1_row2_col14, #T_e5bf1_row2_col15 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_e5bf1_row0_col3 {
#   background-color: #bbdd66;
#   color: #000000;
# }
# #T_e5bf1_row0_col4, #T_e5bf1_row0_col11, #T_e5bf1_row0_col14, #T_e5bf1_row0_col15, #T_e5bf1_row1_col0, #T_e5bf1_row1_col1, #T_e5bf1_row1_col3, #T_e5bf1_row1_col6, #T_e5bf1_row1_col7, #T_e5bf1_row1_col9, #T_e5bf1_row1_col12, #T_e5bf1_row2_col2, #T_e5bf1_row2_col4, #T_e5bf1_row2_col5, #T_e5bf1_row2_col8, #T_e5bf1_row2_col10, #T_e5bf1_row2_col13 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_e5bf1_row0_col9 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_e5bf1_row0_col10 {
#   background-color: #c9e466;
#   color: #000000;
# }
# #T_e5bf1_row0_col13 {
#   background-color: #359a66;
#   color: #f1f1f1;
# }
# #T_e5bf1_row1_col2 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_e5bf1_row1_col8 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_e5bf1_row1_col11 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_e5bf1_row1_col14 {
#   background-color: #68b366;
#   color: #f1f1f1;
# }
# #T_e5bf1_row2_col1 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_e5bf1_row2_col6 {
#   background-color: #4aa466;
#   color: #f1f1f1;
# }
# #T_e5bf1_row2_col12 {
#   background-color: #198c66;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e5bf1_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >HeartRate</th>
#       <th class="col_heading level0 col0" >7</th>
#       <th class="col_heading level0 col1" >60</th>
#       <th class="col_heading level0 col2" >65</th>
#       <th class="col_heading level0 col3" >66</th>
#       <th class="col_heading level0 col4" >67</th>
#       <th class="col_heading level0 col5" >68</th>
#       <th class="col_heading level0 col6" >70</th>
#       <th class="col_heading level0 col7" >75</th>
#       <th class="col_heading level0 col8" >76</th>
#       <th class="col_heading level0 col9" >77</th>
#       <th class="col_heading level0 col10" >78</th>
#       <th class="col_heading level0 col11" >80</th>
#       <th class="col_heading level0 col12" >82</th>
#       <th class="col_heading level0 col13" >86</th>
#       <th class="col_heading level0 col14" >88</th>
#       <th class="col_heading level0 col15" >90</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >RiskLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5bf1_level0_row0" class="row_heading level0 row0" >high risk</th>
#       <td id="T_e5bf1_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_e5bf1_row0_col1" class="data row0 col1" >20</td>
#       <td id="T_e5bf1_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_e5bf1_row0_col3" class="data row0 col3" >25</td>
#       <td id="T_e5bf1_row0_col4" class="data row0 col4" >5</td>
#       <td id="T_e5bf1_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_e5bf1_row0_col6" class="data row0 col6" >43</td>
#       <td id="T_e5bf1_row0_col7" class="data row0 col7" >6</td>
#       <td id="T_e5bf1_row0_col8" class="data row0 col8" >20</td>
#       <td id="T_e5bf1_row0_col9" class="data row0 col9" >25</td>
#       <td id="T_e5bf1_row0_col10" class="data row0 col10" >9</td>
#       <td id="T_e5bf1_row0_col11" class="data row0 col11" >48</td>
#       <td id="T_e5bf1_row0_col12" class="data row0 col12" >0</td>
#       <td id="T_e5bf1_row0_col13" class="data row0 col13" >22</td>
#       <td id="T_e5bf1_row0_col14" class="data row0 col14" >30</td>
#       <td id="T_e5bf1_row0_col15" class="data row0 col15" >19</td>
#     </tr>
#     <tr>
#       <th id="T_e5bf1_level0_row1" class="row_heading level0 row1" >low risk</th>
#       <td id="T_e5bf1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e5bf1_row1_col1" class="data row1 col1" >33</td>
#       <td id="T_e5bf1_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_e5bf1_row1_col3" class="data row1 col3" >44</td>
#       <td id="T_e5bf1_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_e5bf1_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_e5bf1_row1_col6" class="data row1 col6" >126</td>
#       <td id="T_e5bf1_row1_col7" class="data row1 col7" >7</td>
#       <td id="T_e5bf1_row1_col8" class="data row1 col8" >55</td>
#       <td id="T_e5bf1_row1_col9" class="data row1 col9" >56</td>
#       <td id="T_e5bf1_row1_col10" class="data row1 col10" >2</td>
#       <td id="T_e5bf1_row1_col11" class="data row1 col11" >39</td>
#       <td id="T_e5bf1_row1_col12" class="data row1 col12" >10</td>
#       <td id="T_e5bf1_row1_col13" class="data row1 col13" >7</td>
#       <td id="T_e5bf1_row1_col14" class="data row1 col14" >21</td>
#       <td id="T_e5bf1_row1_col15" class="data row1 col15" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e5bf1_level0_row2" class="row_heading level0 row2" >mid risk</th>
#       <td id="T_e5bf1_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_e5bf1_row2_col1" class="data row2 col1" >21</td>
#       <td id="T_e5bf1_row2_col2" class="data row2 col2" >3</td>
#       <td id="T_e5bf1_row2_col3" class="data row2 col3" >18</td>
#       <td id="T_e5bf1_row2_col4" class="data row2 col4" >5</td>
#       <td id="T_e5bf1_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_e5bf1_row2_col6" class="data row2 col6" >102</td>
#       <td id="T_e5bf1_row2_col7" class="data row2 col7" >6</td>
#       <td id="T_e5bf1_row2_col8" class="data row2 col8" >56</td>
#       <td id="T_e5bf1_row2_col9" class="data row2 col9" >15</td>
#       <td id="T_e5bf1_row2_col10" class="data row2 col10" >35</td>
#       <td id="T_e5bf1_row2_col11" class="data row2 col11" >30</td>
#       <td id="T_e5bf1_row2_col12" class="data row2 col12" >9</td>
#       <td id="T_e5bf1_row2_col13" class="data row2 col13" >26</td>
#       <td id="T_e5bf1_row2_col14" class="data row2 col14" >8</td>
#       <td id="T_e5bf1_row2_col15" class="data row2 col15" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
data_proc = data.drop(data.index[data.HeartRate == 7])

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(data=data, x="HeartRate", kde=True, ax=ax[0])
sns.histplot(data=data_proc, x="HeartRate", kde=True, ax=ax[1])
ax[0].set_title("Original HeartRate Distribution")
ax[1].set_title("Processed HeartRate Distribution")
plt.show()

# %%
data_proc = data_proc.drop(["HeartRate"], axis=1)

# %%
# Original Dataset
X = data.drop("RiskLevel", axis=1)
y = data.RiskLevel
x_train, x_test, y_train, y_test = split(X, y, test_size=0.2, random_state=1)

# Processed Dataset
X_proc = data_proc.drop("RiskLevel", axis=1)
y_proc = data_proc.RiskLevel
x_train_proc, x_test_proc, y_train_proc, y_test_proc = split(X_proc, y_proc, test_size=0.2, random_state=1)

print(f"Original data has {x_train.shape[0]} train data and {x_test.shape[0]} test data\n")
print(f"Processes data has {x_train_proc.shape[0]} train data and {x_test_proc.shape[0]} test data")
# Out:
# Original data has 811 train data and 203 test data
#
# Processes data has 809 train data and 203 test data

# %%
# Using original dataset
rf = RandomForestClassifier(random_state=100)
rf.fit(x_train, y_train)
y_pred = rf.predict(x_test)
print(f"Original Dataset Accuracy: {accuracy_score(y_test, y_pred)}")

# Using processed dataset
rf2 = RandomForestClassifier(random_state=100)
rf2.fit(x_train_proc, y_train_proc)
y_pred = rf2.predict(x_test_proc)
print(f"Processed Dataset Accuracy: {accuracy_score(y_test_proc, y_pred)}")
# Out:
# Original Dataset Accuracy: 0.8669950738916257
# Processed Dataset Accuracy: 0.8916256157635468

# %% [markdown]
# 8.3 Hyperparameter Tuning¶

# %%
params = {
    "n_estimators": [10, 20, 50, 100],
    "criterion": ["gini", "entropy"]
}
rf = RandomForestClassifier(random_state=100)
grid = GridSearchCV(rf, params, cv=10)
grid.fit(x_train_proc, y_train_proc)
print("Best hyperparameter:", grid.best_params_)
# Out:
# Best hyperparameter: {'criterion': 'gini', 'n_estimators': 50}

# %%
pd.DataFrame(grid.cv_results_).sort_values(by="rank_test_score")[["params", "mean_test_score", "rank_test_score"]]
# Out:
#                                           params  mean_test_score  \
# 2      {'criterion': 'gini', 'n_estimators': 50}         0.831867
# 3     {'criterion': 'gini', 'n_estimators': 100}         0.830648
# 7  {'criterion': 'entropy', 'n_estimators': 100}         0.828179
# 6   {'criterion': 'entropy', 'n_estimators': 50}         0.828164
# 1      {'criterion': 'gini', 'n_estimators': 20}         0.823241
# 5   {'criterion': 'entropy', 'n_estimators': 20}         0.822006
# 4   {'criterion': 'entropy', 'n_estimators': 10}         0.818210
# 0      {'criterion': 'gini', 'n_estimators': 10}         0.808302
#
#    rank_test_score
# 2                1
# 3                2
# 7                3
# 6                4
# 1                5
# 5                6
# 4                7
# 0                8

# %%
y_pred = grid.predict(x_test_proc)
print(f"Processed Dataset Accuracy: {accuracy_score(y_test_proc, y_pred)}")
# Out:
# Processed Dataset Accuracy: 0.9014778325123153

# %%
labels = np.unique(y_pred)
sns.heatmap(confusion_matrix(y_test_proc, y_pred), annot=True, xticklabels=labels, yticklabels=labels, cmap="coolwarm")
plt.show()
